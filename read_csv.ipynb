# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd/content/gdrive/My Drive/pandas
# Out:
# /content/gdrive/My Drive/pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('./data/friend_list.csv')
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern

# %%
df.head(2)
# Out:
#     name  age        job
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern

# %%
df.tail(2)
# Out:
#     name  age      job
# 4  Brian   45  manager
# 5  Chris   25   intern

# %%
# 구분이 콤마가 아닌 탭으로 되어있는 파일
df=pd.read_csv('./data/friend_list_tab.txt',delimiter='\t')
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern

# %%
#파일에 헤더가 없어서 열마다 타이틀이 없는 경우
df = pd.read_csv('data/friend_list_no_head.csv', header = None)
df
# Out:
#        0   1          2
# 0   John  20    student
# 1  Jenny  30  developer
# 2   Nate  30    teacher
# 3  Julia  40    dentist
# 4  Brian  45    manager
# 5  Chris  25     intern

# %%
df.columns = ['name', 'age', 'job']

# %%
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern
